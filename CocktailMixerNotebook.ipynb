# %%
# # from urllib.request import urlopen
# import requests

# url = 'https://cocktailenthusiast.com/drinks/'
# r = requests.get(url)
# r.text
# Out:
# '<html>\r\n<head><title>403 Forbidden</title></head>\r\n<body bgcolor="white">\r\n<center><h1>403 Forbidden</h1></center>\r\n<hr><center>nginx</center>\r\n</body>\r\n</html>\r\n'

# %%
import requests
url = 'https://cocktailenthusiast.com/drinks'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
result = requests.get(url, headers=headers)

# %%
import pandas as pd
from bs4 import BeautifulSoup
soup = BeautifulSoup(result.text)
# Out:
# /Users/Shreyash/anaconda/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/Shreyash/anaconda/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
element = soup.findAll('article')

#data = soup.findAll('div',attrs={'class':'makers'})
#for div in data:
#    links = div.findAll('a')
#    for a in links:
#        print "http://www.gsmarena.com/" + a['href']
for a in element:
    links = a.findAll('a', href=True)
    for b in links:
        print (b['href'])
# Out:
# /recipe/aberdeen-flip
# /absinthe-frappe-recipe
# /the-adonis-cocktail-recipe
# /alaskan-cocktail
# /hendricks-gin-cocktail-recipes
# /the-algonquin-cocktail
# /recipe/a-lister-an-entourage-inspired-cocktail-recipe
# /americano-cocktail
# /4th-of-july-cocktails
# /american-pie-cocktail
# /agwa-de-bolivia-coca-leaf-liqueur
# /7-valentines-day-cocktails-youll-actually-want-to-drink
# /3-simple-cocktails-for-labor-day-weekend
# /valentines-day-cocktails
# /apple-blow-fizz
# /apple-brandy-old-fashioned
# /couple-gin-cocktails-for-drinking-this-fall
# /holiday-cocktail-recipes
# /holiday-cocktail-recipes
# /wine-cocktails
# /arrandas-highball-tequila-cocktail
# /mixing-with-cynar
# /fall-cocktail-recipes
# /seasonal-drinking-with-grey-goose-vodka
# /aviation
# /rethinking-the-aviation-cocktail
# /a-baijiu-cocktail-for-chinese-new-year
# /bald-eagle-cocktail
# /seasonal-drinking-with-grey-goose-vodka
# /wine-cocktails
# /mixing-with-cynar
# /mixology-monday-gin-basil-sour-with-basil-foam
# ...

# %%
df = pd.DataFrame(columns = ['links'], data = [b['href'] for b in links])
df
# Out:
#                                                  links
# 0                                /recipe/aberdeen-flip
# 1                              /absinthe-frappe-recipe
# 2                          /the-adonis-cocktail-recipe
# 3                                    /alaskan-cocktail
# 4                      /hendricks-gin-cocktail-recipes
# 5                              /the-algonquin-cocktail
# 6    /recipe/a-lister-an-entourage-inspired-cocktai...
# 7                                  /americano-cocktail
# 8                               /4th-of-july-cocktails
# 9                               /american-pie-cocktail
# 10                  /agwa-de-bolivia-coca-leaf-liqueur
# 11   /7-valentines-day-cocktails-youll-actually-wan...
# 12           /3-simple-cocktails-for-labor-day-weekend
# 13                           /valentines-day-cocktails
# 14                                    /apple-blow-fizz
# 15                         /apple-brandy-old-fashioned
# ...

# %%
for index, row in df.iterrows():
    url1 = 'https://cocktailenthusiast.com' + row
#     headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
#     pages = requests.get(url, headers = headers)
    r =  requests.get(url1)
    r.text
# Out:
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# <ipython-input-58-1960fdf2cd0a> in <module>()
#       3 #     headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
#       4 #     pages = requests.get(url, headers = headers)
# ----> 5     r =  requests.get(url1)
#       6     r.text
#
# /Users/Shreyash/anaconda/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# /Users/Shreyash/anaconda/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ...
